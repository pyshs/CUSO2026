# %% [markdown]
# # Collecter des données OpenAlex

# %% [markdown]
# ## Découvrir l'API

# %% [markdown]
# Jeter un coup d'oeil ici : https://docs.openalex.org/how-to-use-the-api/api-overview

# %% [markdown]
# Il faut un token

# %%
import yaml
with open('creds.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# https://openalex.org/works?page=1&filter=title_and_abstract.search:%22computational+social+science%22

# %%
import requests

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

params = {
    "q": "computational social science",
    "per-page": 25,
    "page": 1,
}

r = requests.get(url, headers=headers, params=params)
r.raise_for_status()
data = r.json()
#print(data["results"])

# %% [markdown]
# Get all the data

# %%
import requests
import time


keyword = "computational social science"
per_page = 25     
max_results = None 

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

cursor = "*"
all_works = []
n = 0

while True:
    params = {
        "filter": f'title_and_abstract.search:"{keyword}"',
        "per-page": per_page,
        "select": "id,type,primary_location,title,abstract_inverted_index,publication_year,publication_date,open_access,relevance_score",
        "cursor": cursor
    }

    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()
    data = r.json()

    results = data.get("results", [])
    total = data["meta"]["count"]

    if not results:
        break

    all_works.extend(results)
    n += len(results)

    print(f"Fetched {n} / {total} (cursor={cursor})")

    if max_results is not None and n >= max_results:
        break

    cursor = data["meta"].get("next_cursor")
    if not cursor:
        break

    time.sleep(0.2)

print(f"\nDone. Collected {len(all_works)} works total.\n")
# Out:
# Fetched 25 / 2102 (cursor=*)
# Fetched 50 / 2102 (cursor=IlsxOTIuODc5NzUsIDE2MDMyMzg0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDQyMzA2OCddIg==)
# Fetched 75 / 2102 (cursor=IlsxMjYuMjQwMjcsIDE0MjU5NDU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMzc2MTkyMCddIg==)
# Fetched 100 / 2102 (cursor=Ils5OS4xMDIzNiwgMTM4ODUzNDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNDg2NDU0NTg4J10i)
# Fetched 125 / 2102 (cursor=Ils4Mi4zNjYyOCwgMTQ3NDkzNDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMjE3MzM0NDg0J10i)
# Fetched 150 / 2102 (cursor=Ils2Ny42NjQ5OSwgMTY0NDg4MzIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjEzMzc5MzY3J10i)
# Fetched 175 / 2102 (cursor=Ils1OC4wMTMwOTYsIDEzNzQwMTkyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI3ODIxNjIxMSddIg==)
# Fetched 200 / 2102 (cursor=Ils1MS43MzgwNDUsIDE3MDQwNjcyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5ODE5OTIxMSddIg==)
# Fetched 225 / 2102 (cursor=Ils0NS4yNjA0OCwgMTY2MTk5MDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzc5NDEwNzc3J10i)
# Fetched 250 / 2102 (cursor=Ils0Mi4wNTAyLCAxNTA4MzcxMjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4MDc5NjQ3MjUnXSI=)
# Fetched 275 / 2102 (cursor=IlszNy42Mjc2NCwgMTU2Mjg4OTYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyOTYwMzA1MjYwJ10i)
# Fetched 300 / 2102 (cursor=IlszMC4xNjI2NDMsIDEzNTk2NzY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUzNDk0NzczMSddIg==)
# Fetched 325 / 2102 (cursor=IlsxNy40NTI0NCwgMTM4NzE1MjAwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDExNTM5NzkyJ10i)
# Fetched 350 / 2102 (cursor=IlsxMS42ODQ5ODcsIDE2MDMxNTIwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDA2NzU3MCddIg==)
# Fetched 375 / 2102 (cursor=IlsxMC42ODQ5MzEsIDEyOTg5Mzc2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAzNjYzODU3MiddIg==)
# Fetched 400 / 2102 (cursor=IlsxMC40NDQ3NjIsIDE2MTQ5MDI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE1MjMwNDYzMyddIg==)
# Fetched 425 / 2102 (cursor=Ils5LjkwODMzNSwgMTcwMjg1NzYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c3M
4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI1MDU2OTk2MCddIg==)
# Fetched 1100 / 2102 (cursor=IlsyLjkwMTE3OSwgMTM4ODQ0ODAwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjQzNjIwMjkzJ10i)
# Fetched 1125 / 2102 (cursor=IlsyLjc5NTQ1NjQsIDE3MjMyNDgwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMjcwNTYzNyddIg==)
# Fetched 1150 / 2102 (cursor=IlsyLjY0MTQ5MDIsIDE3MjkzODI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMzU3Nzg1OCddIg==)
# Fetched 1175 / 2102 (cursor=IlsyLjUxMTQxMjEsIDE0MDE1ODA4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTY2MDAwNTM0MyddIg==)
# Fetched 1200 / 2102 (cursor=IlsyLjQxODAyMSwgMTcxMTc1NjgwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzk0NTk5OTExJ10i)
# Fetched 1225 / 2102 (cursor=IlsyLjMxODM1OCwgMTcxNDY5NDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0Mzk2NjE3MTU3J10i)
# Fetched 1250 / 2102 (cursor=IlsyLjI0NTcxOTcsIDE1ODIxNTY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNzU5ODQ1OCddIg==)
# Fetched 1275 / 2102 (cursor=IlsyLjEyMzAyMDYsIDE3NTA4OTYwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxMTY3MDU0NyddIg==)
# Fetched 1300 / 2102 (cursor=IlsyLjA0NjEyLCAxNzQ5ODU5MjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTUzMzI5MzEnXSI=)
# Fetched 1325 / 2102 (cursor=IlsxLjg2MzE1MTEsIDE2OTQ0NzY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NzE2NDYzOSddIg==)
# Fetched 1350 / 2102 (cursor=IlsxLjc3MTAxMTYsIDE3NjE3ODI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxNTY5OTExNyddIg==)
# Fetched 1375 / 2102 (cursor=IlsxLjA1NTE1MTIsIDE2OTQxMzEyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NjU0NzQ1OSddIg==)
# Fetched 1400 / 2102 (cursor=IlswLjgzOTMwMjg0LCAxNDMwMzUyMDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDg5OTAyMDgnXSI=)
# Fetched 1425 / 2102 (cursor=IlswLjc2MzgzMDgsIDE0NjA3NjQ4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ2NDYxMjg1NCddIg==)
# Fetched 1450 / 2102 (cursor=IlswLjcxNjA4MDksIDE3Njg0MzUyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyNDI1MTQ0NiddIg==)
# Fetched 1475 / 2102 (cursor=IlswLjY3MjY2MjE0LCAxNzcxMjg2NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMzA3MjMwNzAnXSI=)
# Fetched 1500 / 2102 (cursor=IlswLjY0Nzg1MTE3LCAxNTEwNzkwNDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3Njk5NzU5NDAnXSI=)
# Fetched 1525 / 2102 (cursor=IlswLjYxODE0OTk0LCAxNTQ2MzAwODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTc0MTI4MDgnXSI=)
# Fetched 1550 / 2102 (cursor=IlswLjYxNjcyMDQsIDEzNTY5OTg0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU1Nzk3ODcwJ10i)
# Fetched 1575 / 2102 (cursor=IlswLjU5ODQzNDU3LCAxNzE2MzM2MDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTgyMDI0NDMnXSI=)
# Fetched 1600 / 2102 (cursor=IlswLjU5NjYzNjgsIDE2OTE1MzkyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NTc1MDE3NyddIg==)
# Fetched 1625 / 2102 (cursor=IlswLjU3OTQxNDQsIDEyNjIzMDQwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNjk5NTE5ODcnXSI=)
# Fetched 1650 / 2102 (cursor=IlswLjU3ODUzMzQsIDE3NTA4OTYwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxMTY3NDEwOSddIg==)
# Fetched 1675 / 2102 (cursor=IlswLjU2MjI1MTAzLCAxNDgzMjI4ODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzc3MzMwNTQ2J10i)
# Fetched 1700 / 2102 (cursor=IlswLjU2MDg5MDIsIDE2NzUxMjMyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMxODc2OTM5NSddIg==)
# Fetched 1725 / 2102 (cursor=IlswLjU0NjE4NjE1LCAxNjMxMDU5MjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMDYwMTI3MzQnXSI=)
# Fetched 1750 / 2102 (cursor=IlswLjU0NDcyNTA2LCAxNzA4OTA1NjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTIxOTY4MjcnXSI=)
# Fetched 1775 / 2102 (cursor=IlswLjUzMDYxNTIsIDE3Njk2NDQ4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyODU5MTU5MSddIg==)
# Fetched 1800 / 2102 (cursor=IlswLjUxNjgwMDQsIDE3NjcyMjU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzEyNjE2NzkwMyddIg==)
# Fetched 1825 / 2102 (cursor=IlswLjUxNTYyMTM2LCAxNzA5MDc4NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTIzNzA5NjUnXSI=)
# Fetched 1850 / 2102 (cursor=IlswLjUwMjcxODYsIDE3MjY3MDQwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMjY0NjU0MSddIg==)
# Fetched 1875 / 2102 (cursor=IlswLjUwMTg5ODIsIDE3NDAwOTYwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwNzgwNTYxMCddIg==)
# Fetched 1900 / 2102 (cursor=IlswLjQ4OTc3NTE4LCAxNzE5MjczNjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDAwMDQyMDAnXSI=)
# Fetched 1925 / 2102 (cursor=IlswLjQ4ODg4NjYsIDE2MDI3MjAwMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NjEzNTE3OCddIg==)
# Fetched 1950 / 2102 (cursor=IlswLjQ2NTUyMDgsIDE2NzI1MzEyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3ODM0NTY1MiddIg==)
# Fetched 1975 / 2102 (cursor=IlswLjQ2NDc0NjE4LCAxNzU3ODA4MDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTUwODgyMzEnXSI=)
# Fetched 2000 / 2102 (cursor=IlswLjQ0MzQzMDIsIDE3MjUxNDg4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMzE2MDkwOCddIg==)
# Fetched 2025 / 2102 (cursor=IlswLjQyMzY4MTE0LCAxNjA5NDU5MjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMzE1MDE1MDknXSI=)
# Fetched 2050 / 2102 (cursor=IlswLjM4ODc3NjYsIDE3NDM0NjU2MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQxMzg5MDA3NiddIg==)
# Fetched 2075 / 2102 (cursor=IlswLjM0NjI4MDQsIDE3NjE1MjMyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNzExMzU3MzYzOSddIg==)
# Fetched 2100 / 2102 (cursor=IlswLjMwMjI2MDE2LCAxNzY3OTE2ODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMTk5MzY3ODgnXSI=)
# Fetched 2125 / 2102 (cursor=IlswLjIyOTAyMDk1LCAxNzYwNDg2NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzcxMTgwMzYyMjAnXSI=)
# Fetched 2129 / 2102 (cursor=IlswLjA5NTQzNzE3LCAxMzE0MzE2ODAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDU0NTg4MzcnXSI=)
#
# Done. Collected 2129 works total.

# %% [markdown]
# Sauvegarder les données

# %%
import pickle
import os

os.makedirs("data", exist_ok=True)

with open("data/all_works.pkl", "wb") as f:
    pickle.dump(all_works, f)

# %% [markdown]
# ## Mettre sous la forme d'un dataframe

# %%
def reconstruct_abstract(inv_index):
    if not inv_index:
        return None
    
    # Determine abstract length
    max_position = max(pos for positions in inv_index.values() for pos in positions)
    abstract_words = [None] * (max_position + 1)

    # Place words in correct positions
    for word, positions in inv_index.items():
        for pos in positions:
            abstract_words[pos] = word

    return " ".join([i for i in abstract_words if i is not None])

def extract_journal_name(primary_location):
    try:
        return primary_location["source"]["display_name"]
    except:
        return None

# reconstruct_abstract(all_works[200]["abstract_inverted_index"])

# %%
import pandas as pd
df = pd.DataFrame(all_works)
df["abstract"] = df["abstract_inverted_index"].apply(reconstruct_abstract)
df["journal"] = df["primary_location"].apply(extract_journal_name)
df.to_csv("data/css_openalex_26022026.csv", index=False)
