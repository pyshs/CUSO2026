# %% [markdown]
# # Collecter des données OpenAlex

# %% [markdown]
# ## Découvrir l'API

# %% [markdown]
# Jeter un coup d'oeil ici : https://docs.openalex.org/how-to-use-the-api/api-overview

# %% [markdown]
# Il faut un token. Pour cela on crée un fichier `creds.yaml` qui contient le token récupéré sur le compte que l'on crée sur OpenAlex, et qui contient
#
# ````yaml
# token-openalex: TOKEN
# ````

# %% [markdown]
# Ouvrir le fichier pour récupérer le token

# %%
import yaml
with open('creds.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Faire un test sur une requête

# %% [markdown]
# https://openalex.org/works?page=1&filter=title_and_abstract.search:%22computational+social+science%22

# %%
import requests

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

params = {
    "q": "computational social science",
    "per-page": 25,
    "page": 1,
}

r = requests.get(url, headers=headers, params=params)
r.raise_for_status()
data = r.json()
#print(data["results"])

# %% [markdown]
# Get all the data

# %%
import requests
import time


keyword = "computational social science"
per_page = 25     
max_results = None 

url = "https://api.openalex.org/works"

headers = {
    "Authorization": f"Bearer {config['token-openalex']}"
}

cursor = "*"
all_works = []
n = 0

while True:
    params = {
        "filter": f'title_and_abstract.search:"{keyword}"',
        "per-page": per_page,
        "select": "id,type,primary_location,title,abstract_inverted_index,publication_year,publication_date,open_access,relevance_score",
        "cursor": cursor
    }

    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()
    data = r.json()

    results = data.get("results", [])
    total = data["meta"]["count"]

    if not results:
        break

    all_works.extend(results)
    n += len(results)

    print(f"Fetched {n} / {total} (cursor={cursor})")

    if max_results is not None and n >= max_results:
        break

    cursor = data["meta"].get("next_cursor")
    if not cursor:
        break

    time.sleep(0.2)

print(f"\nDone. Collected {len(all_works)} works total.\n")
# Out:
# Fetched 25 / 2102 (cursor=*)
# Fetched 50 / 2102 (cursor=IlsxOTIuODc5NzUsIDE2MDMyMzg0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDQyMzA2OCddIg==)
# Fetched 75 / 2102 (cursor=IlsxMjYuMjM4LCAxNDI1OTQ1NjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwMDM3NjE5MjAnXSI=)
# Fetched 100 / 2102 (cursor=Ils5OS4xMDIzNiwgMTM4ODUzNDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyNDg2NDU0NTg4J10i)
# Fetched 125 / 2102 (cursor=Ils4Mi4zNjYyOCwgMTQ3NDkzNDQwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMjE3MzM0NDg0J10i)
# Fetched 150 / 2102 (cursor=Ils2Ny42NjQ5OSwgMTY0NDg4MzIwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjEzMzc5MzY3J10i)
# Fetched 175 / 2102 (cursor=Ils1OC4wMTUzLCAxMzc0MDE5MjAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyNzgyMTYyMTEnXSI=)
# Fetched 200 / 2102 (cursor=Ils1MS43MzgwNDUsIDE3MDQwNjcyMDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5ODE5OTIxMSddIg==)
# Fetched 225 / 2102 (cursor=Ils0NS4xNzgyNzYsIDE2NjE5OTA0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3OTQxMDc3NyddIg==)
# Fetched 250 / 2102 (cursor=Ils0Mi4wMTgxNjYsIDE2MzY1MDI0MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNDUxMjAxMSddIg==)
# Fetched 275 / 2102 (cursor=IlszNy42Mjc2NCwgMTU2Mjg4OTYwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyOTYwMzA1MjYwJ10i)
# Fetched 300 / 2102 (cursor=IlszMC4xNjI2ODIsIDEzNTk2NzY4MDAwMDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUzNDk0NzczMSddIg==)
# Fetched 325 / 2102 (cursor=IlsxNy40NTI0NCwgMTM4NzE1MjAwMDAwMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyM
NDAwMDAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTMxNDE4NjAnXSI=)
#
# Done. Collected 2128 works total.

# %% [markdown]
# Sauvegarder les données

# %%
import pickle
import os

os.makedirs("data", exist_ok=True)

with open("data/all_works.pkl", "wb") as f:
    pickle.dump(all_works, f)

# %%
type(all_works)
# Out:
# list

# %%
len(all_works)
# Out:
# 2128

# %%
all_works[0]
# Out:
# {'id': 'https://openalex.org/W2159397589',
#  'type': 'article',
#  'primary_location': {'id': 'doi:10.1126/science.1167742',
#   'is_oa': False,
#   'landing_page_url': 'https://doi.org/10.1126/science.1167742',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S3880285',
#    'display_name': 'Science',
#    'issn_l': '0036-8075',
#    'issn': ['0036-8075', '1095-9203'],
#    'is_oa': False,
#    'is_in_doaj': False,
#    'is_core': True,
#    'host_organization': 'https://openalex.org/P4310315823',
#    'host_organization_name': 'American Association for the Advancement of Science',
#    'host_organization_lineage': ['https://openalex.org/P4310315823'],
#    'host_organization_lineage_names': ['American Association for the Advancement of Science'],
#    'type': 'journal'},
#   'license': None,
#   'license_id': None,
#   'version': 'publishedVersion',
#   'is_accepted': True,
#   'is_published': True,
#   'raw_source_name': 'Science',
#   'raw_type': 'journal-article'},
#  'title': 'Computational Social Science',
#  'abstract_inverted_index': {'A': [0],
#   'field': [1],
#   'is': [2],
#   'emerging': [3],
#   'that': [4, 16],
#   'leverages': [5],
#   'the': [6],
#   'capacity': [7],
#   'to': [8],
#   'collect': [9],
#   'and': [10, 22],
#   'analyze': [11],
#   'data': [12],
#   'at': [13],
#   'a': [14],
#   'scale': [15],
#   'may': [17],
#   'reveal': [18],
#   'patterns': [19],
#   'of': [20],
#   'individual': [21],
#   'group': [23],
#   'behaviors.': [24]},
#  'publication_year': 2009,
#  'publication_date': '2009-02-06',
#  'open_access': {'is_oa': True,
#   'oa_status': 'green',
#   'oa_url': 'http://nrs.harvard.edu/urn-3:HUL.InstRepos:4142693',
#   'any_repository_has_fulltext': True},
#  'relevance_score': 1360.754}

# %% [markdown]
# ## Mettre sous la forme d'un dataframe

# %%
def reconstruct_abstract(inv_index):
    if not inv_index:
        return None
    
    # Determine abstract length
    max_position = max(pos for positions in inv_index.values() for pos in positions)
    abstract_words = [None] * (max_position + 1)

    # Place words in correct positions
    for word, positions in inv_index.items():
        for pos in positions:
            abstract_words[pos] = word

    return " ".join([i for i in abstract_words if i is not None])

def extract_journal_name(primary_location):
    try:
        return primary_location["source"]["display_name"]
    except:
        return None

# reconstruct_abstract(all_works[200]["abstract_inverted_index"])

# %%
import pandas as pd
df = pd.DataFrame(all_works)
df["abstract"] = df["abstract_inverted_index"].apply(reconstruct_abstract)
df["journal"] = df["primary_location"].apply(extract_journal_name)
df.to_csv("data/css_openalex_26022026.csv", index=False)

# %%
df
# Out:
#                                     id          type  \
# 0     https://openalex.org/W2159397589       article
# 1     https://openalex.org/W2070907364       article
# 2     https://openalex.org/W3081158114       article
# 3     https://openalex.org/W3022499311       article
# 4     https://openalex.org/W3174174150       article
# ...                                ...           ...
# 2123  https://openalex.org/W4245458837       article
# 2124  https://openalex.org/W4413141860       article
# 2125  https://openalex.org/W4231832138      paratext
# 2126  https://openalex.org/W4405505218  book-chapter
# 2127  https://openalex.org/W4376626896      paratext
#
#                                        primary_location  \
# 0     {'id': 'doi:10.1126/science.1167742', 'is_oa':...
# 1     {'id': 'doi:10.1140/epjst/e2012-01697-8', 'is_...
# 2     {'id': 'doi:10.1126/science.aaz8170', 'is_oa':...
# 3     {'id': 'doi:10.1146/annurev-soc-121919-054621'...
# 4     {'id': 'doi:10.1038/s41586-021-03659-0', 'is_o...
# ...                                                 ...
# 2123  {'id': 'doi:10.1002/cplx.20383', 'is_oa': Fals...
# 2124  {'id': 'doi:10.22541/au.175494733.30349065/v1'...
# 2125  {'id': 'doi:10.1108/s1746-979120200000016018',...
# 2126  {'id': 'doi:10.70593/978-81-982935-8-9_4', 'is...
# 2127  {'id': 'doi:10.1108/978-1-80455-994-920231019'...
#
#                                                   title  \
# 0                          Computational Social Science
# 1             Manifesto of computational social science
# 2     Computational social science: Obstacles and op...
# 3            Computational Social Science and Sociology
# 4     Integrating explanation and prediction in comp...
# ...                                                 ...
# 2123                                Complexity at large
# 2124  AI-Driven Behavioral and Sociocultural Analysi...
# 2125                                              Index
# 2126  Publishing academic books in emerging fields: ...
# 2127                                              Index
#
#                                 abstract_inverted_index  publication_year  \
# 0     {'A': [0], 'field': [1], 'is': [2], 'emerging'...            2009.0
# 1                                                  None            2012.0
# 2     {'Data': [0], 'sharing,': [1], 'research': [2]...            2020.0
# 3     {'The': [0], 'integration': [1], 'of': [2, 16,...            2020.0
# 4                                                  None            2021.0
# ...                                                 ...               ...
# 2123  {'The': [0, 155, 250, 320, 367, 466, 497, 529,...            2011.0
# 2124  {'Author:': [0], 'Khan': [1], 'Tahsin': [2], '...            2025.0
# 2125  {'Citation': [0], '(2020),': [1], '"Index",': ...            2020.0
# 2126  {'Publishing': [0, 240, 261, 325, 561, 3442, 3...            2024.0
# 2127  {'Citation': [0], '(2023),': [1], '"Index",': ...            2023.0
#
#      publication_date                                        open_access  \
# 0          2009-02-06  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 1          2012-11-01  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...
# 2          2020-08-28  {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# 3          2020-04-28  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...
# 4          2021-06-30  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# ...               ...                                                ...
# 2123       2011-08-26  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...
# 2124       2025-08-11  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
# 2125       2020-10-06  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...
# 2126       2024-12-05  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
# 2127       2023-05-15  {'is_oa': True, 'oa_status': 'gold', 'oa_url':...
#
#       relevance_score                                           abstract  \
# 0         1360.754000  A field is emerging that leverages the capacit...
# 1          498.112580                                               None
# 2          438.540130  Data sharing, research ethics, and incentives ...
# 3          413.034240  The integration of social science with compute...
# 4          408.089800                                               None
# ...               ...                                                ...
# 2123         0.095437  The following news item is taken in part from ...
# 2124         0.087923  Author: Khan Tahsin AbrarAffiliation: Independ...
# 2125         0.067887  Citation (2020), "Index", Härtel, C.E.J., Zerb...
# 2126         0.046431  Publishing academic books in emerging fields p...
# 2127         0.040152  Citation (2023), "Index", Lytras, M.D., Housaw...
#
#                                            journal
# 0                                          Science
# 1     The European Physical Journal Special Topics
# 2                                          Science
# 3                       Annual Review of Sociology
# 4                                           Nature
# ...                                            ...
# 2123                                    Complexity
# 2124                                          None
# 2125          Research on emotion in organizations
# 2126                                          None
# 2127                                          None
#
# [2128 rows x 11 columns]
